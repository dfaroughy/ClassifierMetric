# %%
from jetnet.datasets import JetNet

# %% [markdown]
# # Download JetNet 150

# %%
data_args = {
    "jet_type": ["t"], 
    "data_dir": "../data/jetnet",
    "particle_features": ["etarel", "phirel", "ptrel"],
    "num_particles": 150}

JetNet.getData(**data_args)
# Out:
# Downloading t150 dataset to ../../data/jetnet/t150.hdf5
# Downloading dataset
# [██████████████████████████████████████████████████] 100%

# %% [markdown]
# # Download jetnet 30

# %%
data_args = {
    "jet_type": ["t"], 
    "data_dir": "../data/jetnet",
    "particle_features": ["etarel", "phirel", "ptrel"],
    "num_particles": 30}

JetNet.getData(**data_args)
# Out:
# Downloading t dataset to ../../data/jetnet/t.hdf5
# Downloading dataset
# [██████████████████████████████████████████████████] 100%
# (array([[[-0.08937275,  0.04990196,  0.09013499],
#          [-0.09187277,  0.03239307,  0.06591985],
#          [-0.08629999,  0.05381214,  0.05811524],
#          ...,
#          [ 0.10062721, -0.09517162,  0.00899024],
#          [ 0.07870565, -0.08357329,  0.00798528],
#          [ 0.15062723, -0.10517669,  0.00778862]],
#
#         [[-0.04333003, -0.1486254 ,  0.2831953 ],
#          [-0.13082999,  0.10900497,  0.2676639 ],
#          [-0.12176098,  0.1073226 ,  0.07125161],
#          ...,
#          [ 0.12252715,  0.08601296,  0.00357968],
#          [ 0.09636954, -0.20795166,  0.00295464],
#          [-0.00832999,  0.15652938,  0.00256421]],
#
#         [[ 0.03982462, -0.04601784,  0.26466238],
#          [ 0.03732484, -0.02730503,  0.12082595],
#          [ 0.04252339, -0.02355015,  0.09244666],
#          ...,
#          [-0.01028778, -0.03223636,  0.0042265 ],
#          [-0.09767541,  0.08654935,  0.00405927],
#          [-0.0776754 ,  0.0015063 ,  0.00368044]],
#
#         ...,
#
#         [[-0.08780347,  0.06745212,  0.1314639 ],
#          [-0.09101599,  0.07103301,  0.08231904],
#          [-0.09175687,  0.06340036,  0.06988488],
#          ...,
#          [-0.06383187,  0.07630338,  0.01087758],
#          [-0.08313285,  0.08181804,  0.00951968],
#          [-0.07883187,  0.0662979 ,  0.00929287]],
#
#         [[-0.01018722,  0.07031117,  0.18747492],
#          [ 0.03234064, -0.15259495,  0.11415835],
#          [-0.00665458,  0.07900701,  0.09662919],
#          ...,
#          [ 0.03984064, -0.17010394,  0.00644292],
#          [ 0.01484063, -0.17510645,  0.00494487],
#          [ 0.02484064, -0.15009348,  0.00444842]],
#
#         [[ 0.01585125, -0.00917705,  0.06844322],
#          [ 0.00373955, -0.00692299,  0.06405617],
#          [-0.05414881, -0.04419499,  0.05659747],
#          ...,
#          [-0.00914886, -0.03919203,  0.01190642],
#          [ 0.0198712 , -0.03559301,  0.0091666 ],
#          [-0.13414887, -0.02418456,  0.00888111]]], dtype=float32),
#  array([[ 2.00000000e+00,  1.04752722e+03,  3.26872766e-01,
#           1.73815674e+02,  3.00000000e+01],
#         [ 2.00000000e+00,  1.05458093e+03, -7.64169991e-01,
#           2.28857666e+02,  3.00000000e+01],
#         [ 2.00000000e+00,  1.03028650e+03, -9.84824598e-01,
#           9.37527847e+01,  3.00000000e+01],
#         ...,
#         [ 2.00000000e+00,  9.38494995e+02,  3.71331871e-01,
#           1.28739365e+02,  3.00000000e+01],
#         [ 2.00000000e+00,  1.00236346e+03,  8.26593563e-02,
#           1.16806000e+02,  3.00000000e+01],
#         [ 2.00000000e+00,  1.03374353e+03, -1.25335121e+00,
#           1.17115044e+02,  3.00000000e+01]]))
